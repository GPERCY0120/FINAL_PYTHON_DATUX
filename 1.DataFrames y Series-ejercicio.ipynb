# %% [markdown]
# # Importar Pandas

# %%
#importa pandas
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.4'

# %% [markdown]
# # Crear una Serie

# %% [markdown]
# Explore series en python en el siguiente [link](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) en las primeras lineas del documento

# %%
# Crea una Serie de los numeros 10, 20 and 10.
s1 = pd.Series([10,20,10])
s1
# Out:
# 0    10
# 1    20
# 2    10
# dtype: int64

# %%
# Crea una Serie con tres objetos: 'rojo', 'verde', 'azul'
s2 = pd.Series(['rojo', 'verde', 'azul'])
s2
# Out:
# 0     rojo
# 1    verde
# 2     azul
# dtype: object

# %% [markdown]
# # Crear un Dataframe

# %%
# Crea un dataframe vacío llamado 'df'
df= pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Crea una nueva columna en el dataframe, y asignale la primera serie que has creado
df["Serie Numeros"]=s1
df
# Out:
#    Serie Numeros
# 0             10
# 1             20
# 2             10

# %%
# Crea otra columna en el dataframe y asignale la segunda Serie que has creado
df["Serie Colores"]=s2
df
# Out:
#    Serie Numeros Serie Colores
# 0             10          rojo
# 1             20         verde
# 2             10          azul

# %% [markdown]
# # Leer un dataframe

# %%
# Lee el archivo llamado 'avengers.csv" localizado en la carpeta "data" y crea un DataFrame, llamado 'avengers'. 
# El archivo está localizado en "data/avengers.csv"
ruta="./src/pandas/avenger.xlsx"
df_Avenger=pd.read_excel(ruta)
df_Avenger
# Out:
#                                 URL                       nombre  \
# 0    http://marvel.wikia.com/Henry_    Henry Jonathan "Hank" Pym
# 1    http://marvel.wikia.com/Janet_               Janet van Dyne
# 2    http://marvel.wikia.com/Anthon  Anthony Edward "Tony" Stark
# 3    http://marvel.wikia.com/Robert          Robert Bruce Banner
# 4    http://marvel.wikia.com/Thor_O                 Thor Odinson
# ..                              ...                          ...
# 168  http://marvel.wikia.com/Eric_B                  Eric Brooks
# 169  http://marvel.wikia.com/Adam_B                Adam Brashear
# 170  http://marvel.wikia.com/Victor               Victor Alvarez
# 171  http://marvel.wikia.com/Ava_Ay                    Ava Ayala
# 172  http://marvel.wikia.com/Kaluu_                        Kaluu
#
#      n_apariciones actual  genero  fecha_inicio            Notes
# 0             1269    YES    MALE          1963  Merged with Ult
# 1             1165    YES  FEMALE          1963  Dies in Secret
# 2             3068    YES    MALE          1963  Death: "Later w
# 3             2089    YES    MALE          1963  Dies in Ghosts
# 4             2402    YES    MALE          1963  Dies in Fear It
# ..             ...    ...     ...           ...              ...
# 168            198    YES    MALE          2013              NaN
# 169             29    YES    MALE          2014              NaN
# 170             45    YES    MALE          2014              NaN
# 171             49    YES  FEMALE          2014              NaN
# 172             35    YES    MALE          2015              NaN
#
# [173 rows x 7 columns]

# %% [markdown]
# # Inspeccionar un dataframe

# %%
# Muestra las primeras 5 filas del DataFrame.
df_Avenger.head()
# Out:
#                               URL                       nombre  n_apariciones  \
# 0  http://marvel.wikia.com/Henry_    Henry Jonathan "Hank" Pym           1269
# 1  http://marvel.wikia.com/Janet_               Janet van Dyne           1165
# 2  http://marvel.wikia.com/Anthon  Anthony Edward "Tony" Stark           3068
# 3  http://marvel.wikia.com/Robert          Robert Bruce Banner           2089
# 4  http://marvel.wikia.com/Thor_O                 Thor Odinson           2402
#
#   actual  genero  fecha_inicio            Notes
# 0    YES    MALE          1963  Merged with Ult
# 1    YES  FEMALE          1963  Dies in Secret
# 2    YES    MALE          1963  Death: "Later w
# 3    YES    MALE          1963  Dies in Ghosts
# 4    YES    MALE          1963  Dies in Fear It

# %%
# Muestra las primeras 10 filas del DataFrame. 
df_Avenger.head(10)
# Out:
#                               URL                       nombre  n_apariciones  \
# 0  http://marvel.wikia.com/Henry_    Henry Jonathan "Hank" Pym           1269
# 1  http://marvel.wikia.com/Janet_               Janet van Dyne           1165
# 2  http://marvel.wikia.com/Anthon  Anthony Edward "Tony" Stark           3068
# 3  http://marvel.wikia.com/Robert          Robert Bruce Banner           2089
# 4  http://marvel.wikia.com/Thor_O                 Thor Odinson           2402
# 5  http://marvel.wikia.com/Richar       Richard Milhouse Jones            612
# 6  http://marvel.wikia.com/Steven                Steven Rogers           3458
# 7  http://marvel.wikia.com/Clint_       Clinton Francis Barton           1456
# 8  http://marvel.wikia.com/Pietro              Pietro Maximoff            769
# 9  http://marvel.wikia.com/Wanda_               Wanda Maximoff           1214
#
#   actual  genero  fecha_inicio            Notes
# 0    YES    MALE          1963  Merged with Ult
# 1    YES  FEMALE          1963  Dies in Secret
# 2    YES    MALE          1963  Death: "Later w
# 3    YES    MALE          1963  Dies in Ghosts
# 4    YES    MALE          1963  Dies in Fear It
# 5    YES    MALE          1963              NaN
# 6    YES    MALE          1964  Dies at the end
# 7    YES    MALE          1965  Dies in explodi
# 8    YES    MALE          1965  Dies in House o
# 9    YES  FEMALE          1965  Dies in Uncanny

# %%
# Muestra las últimas 5 filas del DataFrame.
df_Avenger.tail()
# Out:
#                                 URL          nombre  n_apariciones actual  \
# 168  http://marvel.wikia.com/Eric_B     Eric Brooks            198    YES
# 169  http://marvel.wikia.com/Adam_B   Adam Brashear             29    YES
# 170  http://marvel.wikia.com/Victor  Victor Alvarez             45    YES
# 171  http://marvel.wikia.com/Ava_Ay       Ava Ayala             49    YES
# 172  http://marvel.wikia.com/Kaluu_           Kaluu             35    YES
#
#      genero  fecha_inicio Notes
# 168    MALE          2013   NaN
# 169    MALE          2014   NaN
# 170    MALE          2014   NaN
# 171  FEMALE          2014   NaN
# 172    MALE          2015   NaN

# %% [markdown]
# # Tamaño del DataFrame

# %%
# Muestra el tamaño del DataFrame
f,c=df_Avenger.shape
print(f"filas: {f}")
print(f"Columnas: {c}")
# Out:
# filas: 173
# Columnas: 7

# %% [markdown]
# # Data types en un DataFrame

# %%
# Muestra los data types del dataframe
tipo=df_Avenger.dtypes
tipo
# Out:
# URL              object
# nombre           object
# n_apariciones     int64
# actual           object
# genero           object
# fecha_inicio      int64
# Notes            object
# dtype: object

# %% [markdown]
# # Editar el indice (index)

# %%
# Cambia el indice a la columna "fecha_inicio".
df2_Avenger=df_Avenger.set_index("fecha_inicio")
df2_Avenger
# Out:
#                                          URL                       nombre  \
# fecha_inicio
# 1963          http://marvel.wikia.com/Henry_    Henry Jonathan "Hank" Pym
# 1963          http://marvel.wikia.com/Janet_               Janet van Dyne
# 1963          http://marvel.wikia.com/Anthon  Anthony Edward "Tony" Stark
# 1963          http://marvel.wikia.com/Robert          Robert Bruce Banner
# 1963          http://marvel.wikia.com/Thor_O                 Thor Odinson
# ...                                      ...                          ...
# 2013          http://marvel.wikia.com/Eric_B                  Eric Brooks
# 2014          http://marvel.wikia.com/Adam_B                Adam Brashear
# 2014          http://marvel.wikia.com/Victor               Victor Alvarez
# 2014          http://marvel.wikia.com/Ava_Ay                    Ava Ayala
# 2015          http://marvel.wikia.com/Kaluu_                        Kaluu
#
#               n_apariciones actual  genero            Notes
# fecha_inicio
# 1963                   1269    YES    MALE  Merged with Ult
# 1963                   1165    YES  FEMALE  Dies in Secret
# 1963                   3068    YES    MALE  Death: "Later w
# 1963                   2089    YES    MALE  Dies in Ghosts
# 1963                   2402    YES    MALE  Dies in Fear It
# ...                     ...    ...     ...              ...
# 2013                    198    YES    MALE              NaN
# 2014                     29    YES    MALE              NaN
# 2014                     45    YES    MALE              NaN
# 2014                     49    YES  FEMALE              NaN
# 2015                     35    YES    MALE              NaN
#
# [173 rows x 6 columns]

# %% [markdown]
# # Ordenar el indice

# %%
# Ordena el índice de forma descendiente
df2_Avenger.sort_values(by=["fecha_inicio"],ascending=[False])
# Out:
#                                          URL          nombre  n_apariciones  \
# fecha_inicio
# 2015          http://marvel.wikia.com/Kaluu_           Kaluu             35
# 2015          http://marvel.wikia.com/Sam_Al   Sam Alexander             78
# 2014          http://marvel.wikia.com/Ava_Ay       Ava Ayala             49
# 2014          http://marvel.wikia.com/Victor  Victor Alvarez             45
# 2014          http://marvel.wikia.com/Adam_B   Adam Brashear             29
# ...                                      ...             ...            ...
# 1900          http://marvel.wikia.com/Emery_    Emery Schaub             26
# 1900          http://marvel.wikia.com/James_   James Santini             40
# 1900          http://marvel.wikia.com/Elvin_   Elvin Haliday            158
# 1900          http://marvel.wikia.com/Willia   William Baker            355
# 1900          http://marvel.wikia.com/Julie_     Julie Power            153
#
#              actual  genero            Notes
# fecha_inicio
# 2015            YES    MALE              NaN
# 2015            YES    MALE              NaN
# 2014            YES  FEMALE              NaN
# 2014            YES    MALE              NaN
# 2014            YES    MALE              NaN
# ...             ...     ...              ...
# 1900            YES    MALE              NaN
# 1900            YES    MALE              NaN
# 1900             NO    MALE              NaN
# 1900             NO    MALE  Died in Identit
# 1900            YES  FEMALE              NaN
#
# [173 rows x 6 columns]

# %% [markdown]
# # Resetear el indice
# Este metodo es un proceso, No retorna nada

# %%
# Resetea el índice
df2_Avenger.reset_index(drop=True, inplace=True)
df2_Avenger
# Out:
#                                 URL                       nombre  \
# 0    http://marvel.wikia.com/Henry_    Henry Jonathan "Hank" Pym
# 1    http://marvel.wikia.com/Janet_               Janet van Dyne
# 2    http://marvel.wikia.com/Anthon  Anthony Edward "Tony" Stark
# 3    http://marvel.wikia.com/Robert          Robert Bruce Banner
# 4    http://marvel.wikia.com/Thor_O                 Thor Odinson
# ..                              ...                          ...
# 168  http://marvel.wikia.com/Eric_B                  Eric Brooks
# 169  http://marvel.wikia.com/Adam_B                Adam Brashear
# 170  http://marvel.wikia.com/Victor               Victor Alvarez
# 171  http://marvel.wikia.com/Ava_Ay                    Ava Ayala
# 172  http://marvel.wikia.com/Kaluu_                        Kaluu
#
#      n_apariciones actual  genero            Notes
# 0             1269    YES    MALE  Merged with Ult
# 1             1165    YES  FEMALE  Dies in Secret
# 2             3068    YES    MALE  Death: "Later w
# 3             2089    YES    MALE  Dies in Ghosts
# 4             2402    YES    MALE  Dies in Fear It
# ..             ...    ...     ...              ...
# 168            198    YES    MALE              NaN
# 169             29    YES    MALE              NaN
# 170             45    YES    MALE              NaN
# 171             49    YES  FEMALE              NaN
# 172             35    YES    MALE              NaN
#
# [173 rows x 6 columns]
